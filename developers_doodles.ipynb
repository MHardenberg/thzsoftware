# %%
import matplotlib.pyplot as plt
import numpy as np
from thzsoftware import math as mt
from thzsoftware.tds import pulse as pt
from thzsoftware import data
from thzsoftware import helper as h
from thzsoftware import math as mt
import pandas as pd
import os

# %%
pulse,_ = h.create_mock_thz_pulse()
plt.plot(pulse)
plt.show()

# %%
pulse_loc = pt.define_thz_pulses(np.arange(100), -pulse)
pulse_locked = pulse.copy()
pulse_locked[pulse_loc[0]:pulse_loc[1]+1] = 20
plt.plot(pulse)
plt.plot(pulse_locked)
plt.show()
# Out:
# reversed!

# %%
pulse_loc
# Out:
# (41, 65)

# %%
plt.plot(pulse[40:65])
plt.show()

# %%
mt.zero_crossings(pulse[40:65])
# Out:
# array([ 0,  6,  8, 14, 15])
